        
        t = np.arange(i0,iN+1)
        f = a*np.exp(-b*np.exp(-c*t))
        ax.semilogy(t,f,c=f'C{cc}')
        if f_max:
            ax.semilogy(t_max, a*np.exp(-1),'o',c=f'C{cc}')
            
    i0,iN = iN+1,xmax
    t = np.arange(i0,iN+1)
    f = a*np.exp(-b*np.exp(-c*t))
    t_max = np.log(b) / c
    ax.semilogy(t,f,'--',c=f'C{cc}', label=country)
    if i0<=t_max and t_max<=iN:
        ax.semilogy(t_max, a*np.exp(-1),'o',c=f'C{cc}')
        
ax.legend()
plt.show()
# Out:
# Spain            967892.7     50.7   0.0434   33   62    90.55
# Spain            200527.5   1721.5   0.1126   62   84    66.16
# Germany        13753648.2     33.5   0.0274   37   60   128.20
# Germany          150542.0   1013.4   0.1054   60   84    65.67
# Italy            221227.2     61.9   0.0643   29   84    64.21
# US                    0.0    -21.8  -0.0082   39   56      nan
# US              1056588.6    430.8   0.0803   56   84    75.58
# Russia       1097047009.2     33.1   0.0132   39   84   264.07

# %%
xmax = 150
fig = plt.figure(figsize=[15,7], tight_layout=True)
ax = fig.gca()
for cc, [country, prm] in enumerate(pp.items()):
    cs, dt = get_country_data(country)

    y = cs.to_numpy().astype(float)
    #ax.semilogy(y, '.', label=country)

    for a,b,c,i0,iN,t_max,r_max,f_max in prm:
        print("{:<10s} {:14.1f} {:8.1f} {:8.4f} {:4d} {:4d} {:8.2f}".format(country, a, b, c, i0, iN, t_max))
        
        t = np.arange(i0,iN+1)
        f = a*np.exp(-b*np.exp(-c*t))
        r = b*c*np.exp(-c*t)
        ax.semilogy(t,f*r,c=f'C{cc}')
        if f_max:
            ax.semilogy(t_max, r_max,'o',c=f'C{cc}')
            
    i0,iN = iN+1,xmax
    t = np.arange(i0,iN+1)
    f = a*np.exp(-b*np.exp(-c*t))
    r = b*c*np.exp(-c*t)
    t_max = np.log(b) / c
    ax.semilogy(t,f*r,'--',c=f'C{cc}', label=country)
    if i0<=t_max and t_max<=iN:
        ax.semilogy(t_max, a*np.exp(-1)*c,'o',c=f'C{cc}')
        
ax.legend()
plt.show()
# Out:
# Spain            967892.7     50.7   0.0434   33   62    90.55
# Spain            200527.5   1721.5   0.1126   62   84    66.16
# Germany        13753648.2     33.5   0.0274   37   60   128.20
# Germany          150542.0   1013.4   0.1054   60   84    65.67
# Italy            221227.2     61.9   0.0643   29   84    64.21
# US                    0.0    -21.8  -0.0082   39   56      nan
# US              1056588.6    430.8   0.0803   56   84    75.58
# Russia       1097047009.2     33.1   0.0132   39   84   264.07
